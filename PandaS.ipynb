# %% [markdown]
# <a href="https://colab.research.google.com/github/RICHAR-SL/pandas/blob/main/PandaS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTAR PANDAS
import pandas as pd
import numpy as np

# %%
#ayuda de pandas

help(pd.Series.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     .. deprecated:: 2.2.0
#
#        Returning a tuple from a callable is deprecated.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on
#       some value.
#     - A tuple of row and column indexes. The tuple elements consist of one of the
#       above inputs, e.g. ``(0, 1)``.
#
# ...

# %% [markdown]
# ***TOMA DE CONTACTOS***:----𝝺

# %%
diccionario= [{'a':1,'b':5,'c':9},{'a':3,'b':5,'c':7}]
DF=pd.DataFrame(diccionario)
DF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-12-2039490051.py in <cell line: 0>()
#       3 DF
#       4
# ----> 5 abc=np.min(DF.to_numpy)
#       6 abc
#
# NameError: name 'np' is not defined

# %%
#crear una seria
serie=pd.Series([2,3,5,6,4],index=['a','b','c','d','e'])
serie
# Out:
# a    2
# b    3
# c    5
# d    6
# e    4
# dtype: int64

# %%
#Borra seie o fila

# %%
serie=pd.Series.drop(['a','b'])
serie
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-29-1507497273.py in <cell line: 0>()
# ----> 1 serie=pd.Series.drop(['a','b'])
#       2 serie
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5354         dtype: float64
#    5355         """
# -> 5356         return super().drop(
#    5357             labels=labels,
#    5358             axis=axis,
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
#Seleccionar filas o series
serie1=serie[['b','d']]
serie1
# Out:
# b    100
# d      6
# dtype: int64

# %%
#Asignacion
serie['b']=100
serie
# Out:
# a      2
# b    100
# c      5
# d      6
# e      4
# dtype: int64

# %%
#operadore
serie4=(serie+serie1)
serie4
# Out:
# a      NaN
# b    200.0
# c      NaN
# d     12.0
# e      NaN
# dtype: float64

# %%
#multiplicacion
serie_mul=serie.mul(serie4,serie)
serie_mul
# Out:
# a        NaN
# b    20000.0
# c        NaN
# d       72.0
# e        NaN
# dtype: float64

# %%
#division

serie_div=serie.div(serie4,serie)
serie_div
# Out:
# a    NaN
# b    0.5
# c    NaN
# d    0.5
# e    NaN
# dtype: float64

# %%
#resta
serie_res=serie.subtract(serie4,serie1)
serie_res
# Out:
# a      NaN
# b   -100.0
# c      NaN
# d     -6.0
# e      NaN
# dtype: float64

# %% [markdown]
# DATAFRAME

# %%
datos = {'Alumno':['Marcos','Juan','Lusia','Eva'],'Nota':[20,10,15,20]}
df=pd.DataFrame(datos,columns=['Alumno','Nota'])
df
# Out:
#    Alumno  Nota
# 0  Marcos    20
# 1    Juan    10
# 2   Lusia    15
# 3     Eva    20

# %% [markdown]
# Entrada,Salida lectura y escritura

# %%
csvaa= df.to_csv('/content/misDatos.csv',index=False,columns=['Alumno','Nota'])
print(csvaa)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-74-2401554277.py in <cell line: 0>()
# ----> 1 csvaa= pd.to_csv('/content/misDatos.csv',index=False,columns=['Alumno','Nota'])
#       2 print(csvaa)
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
#leer dataframe
mis_datos= pd.read_csv('/content/misDatos.csv',header=None,nrows=2)
mis_datos.columns=['Alumno','Nota']
mis_datos.head()
# Out:
#    Alumno  Nota
# 0  Alumno  Nota
# 1  Marcos    20

# %%
df=pd.read_excel('/content/misDatos.xlsx')
df
# Out:
#   Alumno  Nota
# 0  M Mar     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10
